# %%
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt

# show plots without need of calling `.show()`
# %matplotlib inline

# %%
df = pd.read_csv('O-.csv')
df
# Out:
#     Energy     Csc
# 0    4.430  0.0000
# 1    4.590  0.0044
# 2    4.710  0.0110
# 3    5.000  0.0250
# 4    5.290  0.0500
# 5    5.720  0.0913
# 6    6.000  0.1160
# 7    6.190  0.1280
# 8    6.320  0.1330
# 9    6.450  0.1220
# 10   6.640  0.1000
# 11   7.000  0.0485
# 12   7.186  0.0313
# 13   7.300  0.0287
# 14   7.430  0.0360
# 15   7.560  0.0620
# 16   7.700  0.1330
# 17   8.000  0.2300
# 18   8.210  0.2860
# 19   8.350  0.3100
# 20   8.440  0.3160
# 21   8.600  0.3100
# 22   8.760  0.2850
# 23   9.000  0.2440
# 24   9.220  0.2130
# 25   9.400  0.2080
# 26   9.560  0.2140
# 27   9.670  0.2260
# 28   9.890  0.2560
# 29  10.000  0.2850
# 30  10.138  0.3370
# 31  10.460  0.4930
# 32  10.660  0.5500
# 33  10.800  0.5700
# 34  10.900  0.5760
# 35  11.000  0.5760
# 36  11.180  0.5530
# 37  11.500  0.4660
# 38  12.000  0.3270
# 39  12.500  0.2000
# 40  13.000  0.1080
# 41  13.280  0.0688
# 42  13.625  0.0380
# 43  13.800  0.0264
# 44  14.000  0.0230

# %%
a = list(df['Energy'])
b = list(df['Csc'])
plt.plot(a,b)
