# %%
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt

# show plots without need of calling `.show()`
# %matplotlib inline

# %%
df = pd.read_csv('OH-.csv')
df1 = pd.read_csv('O-.csv')
df2 = pd.read_csv('O2O-.csv')

# %%
a = list(df['Energy'])
b = list(df['Csc'])
plt.plot(a,b)

# %%
a1 = list(df1['Energy'])
b1 = list(df1['Csc'])
plt.plot(a1,b1)

# %%
a2 = list(df2['Energy'])
b2 = list(df2['Csc'])
plt.plot(a2,b2)
