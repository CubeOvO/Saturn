# %%
import pandas as pd
import numpy as sp
import numpy as np
import matplotlib.pyplot as plt

# show plots without need of calling `.show()`
# %matplotlib inline

# %%
df = pd.read_csv('data.csv')
df
# Out:
#      Wavelength          Flux  Unnamed: 2
# 0             0  1.000000e-01         NaN
# 1             2  3.000000e+01         2.0
# 2             4  2.500000e+03         2.0
# 3             6  2.800000e+04         2.0
# 4             8  1.800000e+05         2.0
# 5            10  4.000000e+06        30.0
# 6            40  4.700000e+07        10.0
# 7            50  8.300000e+07        10.0
# 8            60  1.030000e+08        10.0
# 9            70  9.400000e+07        10.0
# 10           80  1.200000e+08        10.0
# 11           90  9.900000e+07        10.0
# 12          100  5.600000e+07        10.0
# 13          110  2.500000e+07        10.0
# 14          120  1.200000e+07         8.0
# 15          128  3.070000e+08        25.0
# 16          153  9.000000e+08        23.0
# 17          176  3.700000e+09        29.0
# 18          205  1.400000e+09        26.0
# 19          231  2.650000e+09        39.0
# 20          270  4.500000e+08        10.0
# 21          280  1.540000e+09        20.0
# 22          300  5.840000e+09        20.0
# 23          320  1.160000e+09        20.0
# 24          340  4.500000e+08        20.0
# 25          360  1.310000e+09        10.0
# 26          370  1.770000e+08        30.0
# 27          400  2.760000e+08        30.0
# 28          430  1.770000e+08        30.0
# 29          460  2.120000e+08        20.0
# ..          ...           ...         ...
# 295       26500  4.960000e+15      1000.0
# 296       27500  4.510000e+15      1000.0
# 297       28500  4.090000e+15      1000.0
# 298       29500  3.740000e+15      1000.0
# 299       30500  3.400000e+15      1000.0
# 300       31500  3.180000e+15      1000.0
# 301       32500  2.870000e+15      1000.0
# 302       33500  2.700000e+15      1000.0
# 303       34500  2.470000e+15      1000.0
# 304       35500  2.310000e+15      1000.0
# 305       36500  2.140000e+15      1000.0
# 306       37500  2.010000e+15      1000.0
# 307       38500  1.870000e+15      1000.0
# 308       39500  1.710000e+15      1000.0
# 309       40500  1.600000e+15      1000.0
# 310       41500  1.480000e+15      1000.0
# 311       42500  1.410000e+15      1000.0
# 312       43500  1.330000e+15      1000.0
# 313       44500  1.250000e+15      1000.0
# 314       45500  1.160000e+15      1000.0
# 315       46500  1.060000e+15      1000.0
# 316       47500  9.670000e+14      1000.0
# 317       48500  9.250000e+14      1000.0
# 318       49500  2.840000e+15      3250.0
# 319       52750  6.740000e+15     12250.0
# 320       65000  3.350000e+15     10000.0
# 321       75000  2.220000e+15     10000.0
# 322       85000  1.590000e+15     10000.0
# 323       95000  4.530000e+15     45000.0
# 324      140000  0.000000e+00   -140000.0
#
# [325 rows x 3 columns]

# %%
# calculate the width for each bin

w = df['Wavelength']
f = df['Flux']



def width(w):
    d_w = []
    for i in range(len(w)):
        if i < len(w)-1:
            d_w.append(w[i+1]-w[i])
    return d_w

# %%
df1 = pd.read_csv('hcs2.csv')
df1
# Out:
#         w      cs
# 0       0   0.000
# 1     180   0.067
# 2     196   0.088
# 3     214   0.117
# 4     236   0.155
# 5     264   0.206
# 6     298   0.283
# 7     343   0.414
# 8     404   0.703
# 9     491   1.240
# 10    500   1.500
# 11    626   2.330
# 12   1000   3.300
# 13   1210   5.430
# 14   1390   5.910
# 15   1500   5.700
# 16   1640   7.290
# 17   2000   8.500
# 18   2000   9.510
# 19   2500  11.700
# 20   2570  13.100
# 21   3000  15.200
# 22   3500  18.900
# 23   3580  19.800
# 24   4000  22.300
# 25   4500  25.500
# 26   5000  28.400
# 27   5280  30.200
# 28   5500  31.100
# 29   5890  33.100
# 30   6000  33.500
# 31   6500  35.600
# 32   6760  37.600
# 33   7000  37.100
# 34   7500  38.300
# 35   7940  39.500
# 36   8000  39.200
# 37   8500  39.500
# 38   9000  39.300
# 39   9500  38.500
# 40   9620  39.800
# 41  10000  37.300
# 42  10500  35.800
# 43  11000  33.800
# 44  11500  31.400
# 45  12000  28.500
# 46  12190  28.000
# 47  12500  25.400
# 48  13000  22.000
# 49  13500  18.300
# 50  14000  14.600
# 51  14500  10.600
# 52  15000   7.100
# 53  15500   4.000
# 54  16000   1.700
# 55  16419   0.000

# %%
sw = w[17:283]
sf = f[17:283]
cw = df1['w']
cs = df1['cs']

# %%
len(sf)
# Out:
# 266

# %%
cw_c = []
for i in range(len(sf)+2):
#     print(i)
    found = False
    for j in range(len(cw)):
#         print(j)
        if cw[j]>=sw[i+17] and cw[j]<=sw[i+17]:
            cw_c.append(cs[j])
            found = True
            print(cs[j])
            break
    if not found:
        for j in range(len(cw)-1):
            if j>0:
                if cw[j]>=sw[i+17]:
                    cw_c.append(cs[j-1])
                    found = True
                    break
            else:
                if cw[j]>=sw[i+17]:
                    cw_c.append(cs[j])
                    found = True
                    break
    if not found:
        cw_c.append(0)
        print('error')
        break
# Out:
# 1.5
# 8.5
# 11.7
# error

# %%
type(list(sw))
# Out:
# list

# %%
dw = width(w)
print(dw)
dw = dw[17:283]
print(dw)
# Out:
# [2, 2, 2, 2, 2, 30, 10, 10, 10, 10, 10, 10, 10, 10, 8, 25, 23, 29, 26, 39, 10, 20, 20, 20, 20, 10, 30, 30, 30, 20, 20, 20, 20, 20, 20, 20, 20, 10, 50, 30, 30, 30, 30, 30, 30, 30, 21, 9, 10, 10, 10, 10, 10, 10, 15, 12, 10, 10, 8, 10, 12, 13, 10, 10, 10, 10, 10, 10, 10, 10, 7, 6, 7, 6, 7, 7, 8, 7, 7, 8, 7, 8, 7, 8, 8, 8, 8, 8, 8, 9, 8, 9, 8, 9, 9, 9, 9, 10, 9, 10, 19, 20, 21, 21, 22, 23, 23, 24, 25, 26, 26, 28, 28, 29, 15, 15, 16, 16, 16, 16, 17, 17, 17, 18, 18, 18, 19, 19, 19, 20, 20, 21, 21, 21, 22, 23, 22, 24, 24, 24, 25, 26, 26, 27, 27, 28, 29, 29, 30, 31, 32, 32, 33, 35, 35, 36, 37, 38, 39, 40, 42, 42, 44, 45, 47, 48, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 75, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 200, 600, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 625, 1125, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 3250, 12250, 10000, 10000, 10000, 45000]
# [29, 26, 39, 10, 20, 20, 20, 20, 10, 30, 30, 30, 20, 20, 20, 20, 20, 20, 20, 20, 10, 50, 30, 30, 30, 30, 30, 30, 30, 21, 9, 10, 10, 10, 10, 10, 10, 15, 12, 10, 10, 8, 10, 12, 13, 10, 10, 10, 10, 10, 10, 10, 10, 7, 6, 7, 6, 7, 7, 8, 7, 7, 8, 7, 8, 7, 8, 8, 8, 8, 8, 8, 9, 8, 9, 8, 9, 9, 9, 9, 10, 9, 10, 19, 20, 21, 21, 22, 23, 23, 24, 25, 26, 26, 28, 28, 29, 15, 15, 16, 16, 16, 16, 17, 17, 17, 18, 18, 18, 19, 19, 19, 20, 20, 21, 21, 21, 22, 23, 22, 24, 24, 24, 25, 26, 26, 27, 27, 28, 29, 29, 30, 31, 32, 32, 33, 35, 35, 36, 37, 38, 39, 40, 42, 42, 44, 45, 47, 48, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 75, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 200, 600, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500]

# %%
k_rate = []
height = []
for i in range(len(sw)-1):
    k = cw_c[i]*list(sf)[i]
    k_rate.append(k*(10**-18))
    height.append(k*(10**-18)/dw[i])
plt.yscale('log')
plt.xlim([0,20000])
plt.plot(sw[:-1],height)
sum(k_rate)
# Out:
# 14.201384494449096

# %%
params = {
   'axes.labelsize': 18,
   'font.size': 18,
   'legend.fontsize': 14,
   'xtick.labelsize': 18,
   'ytick.labelsize': 18,
   'figure.figsize': [8,8]
   } 
plt.rcParams.update(params)
plt.yscale('log')
plt.xlim([0,20000])
plt.plot(sw[:-1],height)
plt.xlabel('Wavelength(A)')
plt.ylabel('LOG RATE COEFF')
plt.savefig('HRate.png')
